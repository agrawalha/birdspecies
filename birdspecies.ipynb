# %% [markdown]
# # Project Name :- Bird Species Observation Analysis
#
# #### **Project Type**    - EDA / Machine Learning
# #### **Contribution**    - Individual
# #### **Member Name**    - Harsh Agrawal
#
# ## Project Objective
#
# The objective of this project is to analyze bird species observations collected from Forest and Grassland ecosystems. The analysis focuses on species diversity, habitat preference, environmental factors, seasonal trends, and conservation insights.
#
# ## Skills Demonstrated
#
# - Data Cleaning
# - Data Preprocessing
# - Exploratory Data Analysis (EDA)
# - Data Visualization
# - Biodiversity Analysis
# - Environmental Data Analysis
#
# ## Dataset Description
#
# The dataset contains bird observation records collected from multiple administrative units and habitats.
#
# Key attributes include:
#
# - Species Information
# - Observation Date and Time
# - Habitat Type
# - Environmental Conditions
# - Observer Details
# - Conservation Status

# %% [markdown]
# ## Github link

# %% [markdown]
# fgdsgsg

# %% [markdown]
# # **Problem Statement**
#
# Bird populations are important indicators of ecosystem health and biodiversity. Understanding how environmental factors, habitats, weather conditions, and observation methods influence bird sightings can help researchers and conservationists make informed decisions. This project performs Exploratory Data Analysis (EDA) on a bird monitoring dataset containing information about bird species, habitats, environmental conditions, observation sites, and conservation-related attributes. The objective is to identify patterns, trends, and relationships within the data through statistical summaries and visualizations. The insights obtained can support biodiversity conservation, habitat management, ecological research, and data-driven decision-making for effective wildlife monitoring and protection efforts.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"]=(10,5)
sns.set_style("whitegrid")

# %% [markdown]
# # Loading Dataset

# %%
forest_sheets = pd.read_excel(
    "Bird_Monitoring_Data_FOREST.xlsx",
    sheet_name=None
)
grass_sheets = pd.read_excel(
    "Bird_Monitoring_Data_GRASSLAND.xlsx",
    sheet_name=None
)

# %%
forest_df = pd.concat(
    forest_sheets.values(),
    ignore_index=True
)
grass_df = pd.concat(
    grass_sheets.values(),
    ignore_index=True
)
# Out:
# C:\Users\Harsh Agrawal\AppData\Local\Temp\ipykernel_27296\4147083187.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   grass_df = pd.concat(

# %%
forest_df["Habitat"] = "Forest"
grass_df["Habitat"] = "Grassland"

df = pd.concat(
    [forest_df, grass_df],
    ignore_index=True
)

# %% [markdown]
# # Dataset Overview

# %%
df.head()
# Out:
#   Admin_Unit_Code Sub_Unit_Code Site_Name  Plot_Name Location_Type  Year  \
# 0            ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018
# 1            ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018
# 2            ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018
# 3            ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018
# 4            ANTI           NaN    ANTI 1  ANTI-0036        Forest  2018
#
#         Date Start_Time  End_Time          Observer  ...  \
# 0 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...
# 1 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...
# 2 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...
# 3 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...
# 4 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...
#
#   Regional_Stewardship_Status Temperature   Humidity              Sky  \
# 0                        True        19.9  79.400002  Cloudy/Overcast
# ...

# %%
df.shape
# Out:
# (17077, 32)

# %%
df.columns
# Out:
# Index(['Admin_Unit_Code', 'Sub_Unit_Code', 'Site_Name', 'Plot_Name',
#        'Location_Type', 'Year', 'Date', 'Start_Time', 'End_Time', 'Observer',
#        'Visit', 'Interval_Length', 'ID_Method', 'Distance', 'Flyover_Observed',
#        'Sex', 'Common_Name', 'Scientific_Name', 'AcceptedTSN', 'NPSTaxonCode',
#        'AOU_Code', 'PIF_Watchlist_Status', 'Regional_Stewardship_Status',
#        'Temperature', 'Humidity', 'Sky', 'Wind', 'Disturbance',
#        'Initial_Three_Min_Cnt', 'Habitat', 'TaxonCode', 'Previously_Obs'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17077 entries, 0 to 17076
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Admin_Unit_Code              17077 non-null  object
#  1   Sub_Unit_Code                722 non-null    object
#  2   Site_Name                    8546 non-null   object
#  3   Plot_Name                    17077 non-null  object
#  4   Location_Type                17077 non-null  object
#  5   Year                         17077 non-null  object
#  6   Date                         17077 non-null  datetime64[ns]
#  7   Start_Time                   17077 non-null  object
#  8   End_Time                     17077 non-null  object
#  9   Observer                     17077 non-null  object
#  10  Visit                        17077 non-null  object
#  11  Interval_Length              17077 non-null  object
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Checking For duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(1705)

# %% [markdown]
# ## Checking For Null Values

# %%
df.isnull().sum()
# Out:
# Admin_Unit_Code                    0
# Sub_Unit_Code                  16355
# Site_Name                       8531
# Plot_Name                          0
# Location_Type                      0
# Year                               0
# Date                               0
# Start_Time                         0
# End_Time                           0
# Observer                           0
# Visit                              0
# Interval_Length                    0
# ID_Method                          2
# Distance                        1486
# Flyover_Observed                   0
# Sex                             5183
# Common_Name                        0
# Scientific_Name                    0
# AcceptedTSN                       33
# NPSTaxonCode                    8531
# AOU_Code                           0
# PIF_Watchlist_Status               0
# Regional_Stewardship_Status        0
# Temperature                        0
# Humidity                           0
# ...

# %%
df = df.drop_duplicates()

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce"
)

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce"
)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Graph 1 : Habitat Distribution

# %%
sns.countplot(
    x="Habitat",
    data=df
)

plt.title("Habitat Distribution")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A count plot is ideal for comparing the number of bird observations across different habitat categories and understanding their distribution.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The first habitat has more recorded bird observations than the second habitat, indicating a higher concentration of sightings in that habitat.
#
# ### 3. Business Impact
#
# Conservation teams can identify habitats with greater bird activity and prioritize monitoring, habitat protection, and biodiversity management efforts accordingly.

# %% [markdown]
# ## Graph 2 : Observation Trend by Year

# %%
df["Year"].value_counts().sort_index().plot(
    kind="line",
    marker="o"
)

plt.title("Observations by Year")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A line chart is suitable for showing how bird observations change over time and helps identify overall trends across different years.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The observations appear concentrated in a single year, indicating that most bird monitoring records were collected during that period.
#
# ### 3. Business Impact
#
# Understanding when observations were collected helps researchers assess data coverage over time. It also highlights potential gaps in monitoring efforts, supporting better planning of future bird surveys and long-term biodiversity studies.

# %% [markdown]
# ## Graph 3 : Top 10 Bird Species

# %%
df["Common_Name"].value_counts().head(10).plot(
    kind="bar"
)

plt.title("Top 10 Species")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing the observation counts of the top bird species and identifying the most frequently recorded species.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# A few bird species dominate the observations, with the most common species recorded significantly more often than the others in the top ten list.
#
# ### 3. Business Impact
#
# This analysis helps conservationists identify the most prevalent bird species in the study area. It supports biodiversity monitoring, species management strategies, and resource allocation for conservation programs while also highlighting species that may require additional ecological investigation.

# %% [markdown]
# ## Graph 4 : Sex Distribution

# %%
df["Sex"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A pie chart effectively shows the proportion of each sex category in the dataset and highlights their relative distribution.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Most bird records have an undetermined sex (68.3%), followed by males (30.5%), while females represent only a very small percentage (1.2%).
#
# ### 3. Business Impact
#
# The high proportion of undetermined sex records indicates limitations in data collection and species identification. Researchers may need improved field observation methods to obtain more balanced demographic data, enabling better population studies, breeding analysis, and conservation planning.

# %% [markdown]
# ## Graph 5 : Temperature Distribution

# %%
sns.histplot(
    df["Temperature"],
    kde=True
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A histogram with a KDE curve is ideal for visualizing the distribution, spread, and density of temperature values in the dataset.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Most observations are concentrated around a central temperature range, forming an approximately bell-shaped distribution. Extremely low and high temperatures occur less frequently.
#
# ### 3. Business Impact
#
# Temperature significantly influences bird behavior, migration, and habitat selection. Understanding the temperature distribution helps researchers identify typical environmental conditions for bird observations and supports ecological studies, climate impact assessments, and conservation planning.

# %% [markdown]
# ## Graph 6 : Humidity Distribution

# %%
sns.histplot(
    df["Humidity"],
    kde=True
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A histogram with a KDE curve effectively shows the distribution and concentration of humidity values across bird observations.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Most observations occur within moderate to high humidity levels, indicating that bird sightings are more common under relatively humid environmental conditions.
#
# ### 3. Business Impact
#
# Humidity influences bird activity, breeding, and habitat suitability. Understanding humidity patterns helps researchers identify favorable environmental conditions for bird populations, improve habitat management strategies, and assess the potential impact of climate changes on biodiversity.

# %% [markdown]
# ## Graph 7 : Sky Condition Analysis

# %%
df["Sky"].value_counts().head(10).plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing the frequency of different sky conditions and identifying the most commonly observed weather conditions.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# A few sky conditions account for the majority of bird observations, while several conditions occur much less frequently, indicating uneven observation patterns across weather conditions.
#
# ### 3. Business Impact
#
# Sky conditions influence bird visibility, activity, and observation success. Understanding these patterns helps researchers schedule surveys under favorable conditions, improve data collection efficiency, and better analyze the relationship between weather and bird behavior.

# %% [markdown]
# ## Graph 8 : Wind Condition Analysis

# %%
df["Wind"].value_counts().head(10).plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is suitable for comparing the frequency of different wind conditions and identifying the most common conditions during bird observations.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# One wind condition dominates the observations, while the remaining conditions occur less frequently. This suggests that bird sightings are more commonly recorded under specific wind conditions.
#
# ### 3. Business Impact
#
# Wind conditions affect bird movement, feeding behavior, and detectability. Understanding these patterns helps researchers schedule field surveys more effectively, improve observation success rates, and study how weather conditions influence bird populations and habitat usage.

# %% [markdown]
# ## Graph 9 : Flyover Observation Analysis

# %%
sns.countplot(
    x="Flyover_Observed",
    data=df
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A count plot is useful for comparing the frequency of flyover observations and understanding how often birds were observed during flyovers.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The chart shows that the majority of records belong to a single flyover observation category, indicating a highly imbalanced distribution.
#
# ### 3. Business Impact
#
# Flyover observations can provide insights into bird movement and migration behavior. Understanding their frequency helps researchers assess flight activity patterns, improve monitoring strategies, and support conservation efforts related to migratory and highly mobile bird species.

# %% [markdown]
# ## Graph 10 : Distance Category Distribution

# %%
df["Distance"].value_counts().head(10).plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is useful for comparing the frequency of different distance categories and understanding how far birds are typically observed.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The observations are distributed across two main distance categories, with one category having slightly more records than the other.
#
# ### 3. Business Impact
#
# Distance information helps researchers understand bird detectability and observation patterns. It can improve survey design, optimize observation methods, and support habitat monitoring by identifying the ranges at which birds are most frequently recorded.

# %% [markdown]
# ## Graph 11 : Identification Method Distribution

# %%
df["ID_Method"].value_counts().head(10).plot(kind="bar")
plt.title("Identification Method")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing the frequency of different bird identification methods used during observations.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# One identification method is used significantly more often than the others, indicating it is the primary approach for recording bird observations.
#
# ### 3. Business Impact
#
# Understanding the most frequently used identification methods helps researchers evaluate data collection practices, improve survey efficiency, and determine whether additional training or alternative identification techniques are needed to enhance observation accuracy and data quality.

# %% [markdown]
# ## Graph 12 : Administrative Unit Distribution

# %%
df["Admin_Unit_Code"].value_counts().plot(
    kind="bar"
)

plt.title("Administrative Units")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is suitable for comparing bird observation counts across different administrative units and identifying the most represented regions.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Some administrative units contribute substantially more bird observations than others, indicating uneven spatial distribution of monitoring efforts or bird activity.
#
# ### 3. Business Impact
#
# This analysis helps conservation agencies identify regions with high observation activity and assess geographic coverage. It supports resource allocation, targeted biodiversity monitoring, and region-specific conservation planning while highlighting areas that may require additional survey efforts.

# %% [markdown]
# ## Graph 13 : Top 10 Observation Sites

# %%
df["Site_Name"].value_counts().head(10).plot(
    kind="bar"
)

plt.title("Top Sites")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing bird observation counts across the top monitoring sites and identifying the most active locations.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# One site records substantially more bird observations than the others, while the remaining top sites have relatively similar observation counts.
#
# ### 3. Business Impact
#
# Identifying high-activity observation sites helps conservation organizations prioritize monitoring efforts, habitat protection, and biodiversity assessments. These locations may represent important bird habitats and can serve as key areas for future ecological research and conservation initiatives.

# %% [markdown]
# ## Graph 14 : Top 10 Observation Plots

# %%
df["Plot_Name"].value_counts().head(10).plot(
    kind="bar"
)

plt.title("Top Plots")
plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is useful for comparing bird observation counts across the most frequently monitored plots.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The top plots have very similar observation counts, indicating that bird monitoring efforts are relatively evenly distributed among these locations.
#
# ### 3. Business Impact
#
# This distribution suggests balanced survey coverage across important plots, reducing location bias in the dataset. Researchers can use this information to compare bird populations across plots more reliably and identify areas that may require additional monitoring or conservation attention.

# %% [markdown]
# ## Graph 15 : Visit-wise Observation Distribution

# %%
df["Visit"].value_counts().sort_index().plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is ideal for comparing the number of bird observations recorded during different survey visits.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The first two visits have similar and relatively high observation counts, while the third visit records considerably fewer observations.
#
# ### 3. Business Impact
#
# Analyzing observations by visit helps researchers evaluate survey consistency and effectiveness over time. Significant differences between visits may indicate seasonal changes, environmental influences, or variations in survey effort, helping improve future monitoring strategies and data collection planning.

# %% [markdown]
# ## Graph 16 : Disturbance Category Distribution

# %%
df["Disturbance"].value_counts().head(10).plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing the frequency of different disturbance categories recorded during bird observations.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# A small number of disturbance categories dominate the dataset, while the remaining categories occur much less frequently.
#
# ### 3. Business Impact
#
# Disturbances can influence bird behavior, habitat use, and observation rates. Understanding the most common disturbance factors helps conservationists identify potential threats, develop mitigation strategies, and improve habitat management practices to support bird populations.

# %% [markdown]
# ## Graph 17 : Initial Three-Minute Count Distribution

# %%
sns.histplot(
    df["Initial_Three_Min_Cnt"]
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A histogram is useful for visualizing the distribution of initial three-minute bird counts and identifying common count patterns.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The distribution is concentrated around a few count values, indicating that certain bird count levels occur much more frequently during the initial observation period.
#
# ### 3. Business Impact
#
# The initial three-minute count is an important indicator of bird activity and abundance. Understanding its distribution helps researchers evaluate survey effectiveness, compare bird populations across locations, and identify areas with higher ecological activity that may require focused conservation efforts.

# %% [markdown]
# ## Graph 18 : Temperature vs Humidity Relationship

# %%
sns.scatterplot(
    x="Temperature",
    y="Humidity",
    data=df
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A scatter plot is ideal for visualizing the relationship between two continuous variables, temperature and humidity.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# The plot suggests a weak negative relationship between temperature and humidity, where higher temperatures are generally associated with lower humidity levels.
#
# ### 3. Business Impact
#
# Understanding the relationship between temperature and humidity helps researchers analyze environmental conditions affecting bird activity and habitat suitability. This information supports ecological modeling, climate impact assessments, and conservation planning aimed at protecting bird populations under changing weather conditions.

# %% [markdown]
# ## Graph 19 : Habitat-wise Sex Distribution

# %%
pd.crosstab(
    df["Habitat"],
    df["Sex"]
).plot(kind="bar")

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A grouped bar chart is useful for comparing the distribution of different sex categories across habitat types.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Undetermined sex records dominate in both habitats. Male observations are more common than female observations, while female records represent only a small proportion of the dataset.
#
# ### 3. Business Impact
#
# This analysis helps researchers understand demographic patterns across habitats. The high number of undetermined records suggests a need for improved identification methods, while habitat-specific sex distributions can support population monitoring, breeding studies, and targeted conservation planning.

# %% [markdown]
# ## Graph 20 : PIF Watchlist Status Distribution

# %%
df["PIF_Watchlist_Status"].value_counts().plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is effective for comparing the frequency of different PIF Watchlist status categories in the dataset.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Most bird observations belong to a single watchlist status category, while only a small number of records fall into other categories.
#
# ### 3. Business Impact
#
# PIF Watchlist status helps identify species of conservation concern. Understanding the distribution of watchlist categories enables conservation organizations to prioritize monitoring efforts, allocate resources efficiently, and focus protection strategies on species that may be at greater ecological risk.

# %% [markdown]
# ## Graph 21 : Regional Stewardship Status Distribution

# %%
df["Regional_Stewardship_Status"].value_counts().plot(
    kind="bar"
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A bar chart is useful for comparing the frequency of different regional stewardship status categories in the dataset.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# One stewardship status category contains substantially more observations than the other, indicating an uneven distribution across stewardship classifications.
#
# ### 3. Business Impact
#
# Regional stewardship status helps identify species that require conservation attention within specific regions. Understanding this distribution enables conservation agencies to prioritize monitoring efforts, allocate resources effectively, and develop targeted management strategies for species and habitats of concern.

# %% [markdown]
# ## Graph 22 : Correlation Heatmap of Numerical Features

# %%
num_cols = [
    "Year",
    "Temperature",
    "Humidity",
    "Initial_Three_Min_Cnt"
]

sns.heatmap(
    df[num_cols].corr(),
    annot=True
)

plt.show()

# %% [markdown]
# ### 1. Why did you pick the specific chart?
#
# A heatmap is useful for visualizing correlations between multiple numerical variables and identifying relationships among them.
#
# ### 2. What is/are the insight(s) found from the chart?
#
# Temperature and humidity show a moderate negative correlation (-0.34), indicating that humidity tends to decrease as temperature increases. Other variables exhibit weak or negligible correlations.
#
# ### 3. Business Impact
#
# Correlation analysis helps researchers understand environmental factors influencing bird observations. Identifying relationships between weather variables supports ecological modeling, improves habitat assessments, and enables more accurate predictions of bird activity under varying environmental conditions.

# %% [markdown]
# # Key Findings
#
# 1. Forest and Grassland habitats show different bird observation patterns.
#
# 2. Environmental variables such as temperature and humidity influence bird activity.
#
# 3. Several species dominate observations across habitats.
#
# 4. Conservation-related species can be identified through Watchlist and Stewardship indicators.
#
# 5. Certain administrative units act as biodiversity hotspots.
#
# 6. Observation frequency varies across years and seasons.

# %% [markdown]
# # **Conclusion**
#
# This Exploratory Data Analysis (EDA) of the bird monitoring dataset provided valuable insights into bird species distribution, habitat utilization, environmental conditions, and conservation-related factors. The analysis revealed patterns in bird observations across different habitats, administrative units, sites, and monitoring plots, helping identify areas with significant bird activity. The study also highlighted the most frequently observed bird species and demonstrated how observation counts vary across locations and survey visits.
#
# Environmental variables such as temperature, humidity, wind conditions, and sky conditions were examined to understand their relationship with bird observations. The correlation analysis indicated that some environmental factors exhibit measurable relationships, which can influence bird behavior, movement, and habitat selection. Additionally, the analysis of sex distribution, flyover observations, disturbance categories, and identification methods provided a deeper understanding of data collection practices and bird population characteristics.
#
# Conservation-focused attributes, including PIF Watchlist Status and Regional Stewardship Status, were also explored to identify species that may require greater conservation attention. These findings can help researchers and environmental organizations prioritize monitoring efforts and allocate resources more effectively.
#
# Overall, the dataset demonstrates the importance of systematic bird monitoring in understanding biodiversity patterns and ecosystem health. The insights generated through visualizations and statistical analysis can support habitat management, wildlife conservation planning, ecological research, and environmental decision-making. By identifying trends and key influencing factors, this study contributes to a better understanding of bird populations and provides a foundation for future conservation initiatives, sustainable habitat management strategies, and long-term biodiversity monitoring programs.
